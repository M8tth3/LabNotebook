# %%
# %%html
#
# <style>
#     label{
#     text-align: left;
#     clear: both;
#     float:left;
#     margin-left:2px;
#     }
#     #0
#     {
#         display:block;
#     }
#     #1
#     {
#         margin-left:10px;
#         display: none;
#     }
#     #2
#     {
#         margin-left:10px;
#         display:none;
#     }
#
# </style>
#
# <div class="battleOptions">
#     <div class="attack">
#         <label for="attack" id="0" type="text" > > </label>
#         <p id="attack"> Attack</p>
#     </div>
#
#     <div id="Heal">
#         <label for="heal" id="1" type="text" > > </label>
#         <p id="heal">Heal</p>
#     </div>
#
#     <div id="Items">
#         <label for="Items" id="2" type="text" > > </label>
#         <p id="Items">Items</p>
#     </div>
# </div>
#
#
# <script>
#     var currentAction=0;
#     window.addEventListener("keypress", function(keyPressed){
#         if(keyPressed.key === "ArrowDown")
#         {
#             currentAction++;
#             action = document.getElementById(`${currentAction}`)
#             action.style.display="block";
#             # every time the user presses down, add a counter by one and assign each action a number. then hide every other label by getElementbyId by number.
#         }
#     })
# </script>
# Out:
# <style>
#     label{
#     text-align: left;
#     clear: both;
#     float:left;
#     margin-left:2px;
#     }
#     #0
#     {
#         display:block;
#     }
#     #1
#     {
#         margin-left:10px;
#         display: none;
#     }
#     #2
#     {
#         margin-left:10px;
#         display:none;
#     }
#
# </style>
#
# <div class="battleOptions">
#     <div class="attack">
#         <label for="attack" id="0" type="text" > > </label>
#         <p id="attack"> Attack</p>
#     </div>
#
#     <div id="Heal">
#         <label for="heal" id="1" type="text" > > </label>
#         <p id="heal">Heal</p>
#     </div>
#
#     <div id="Items">
#         <label for="Items" id="2" type="text" > > </label>
#         <p id="Items">Items</p>
#     </div>
# </div>
#
#
# <script>
#     var currentAction=0;
#     window.addEventListener("keypress", function(keyPressed){
#         if(keyPressed.key === "ArrowDown")
#         {
#             currentAction++;
# ...
